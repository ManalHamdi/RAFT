# %% [markdown]
# # ACDC dataset

# %% [markdown]
# We visualize 1 sequence and its corresponding template using average.

# %%
import torch
import datasets as datasets
import matplotlib.pyplot as plt

# %%
train_dataset = datasets.ACDCDataset("../datasets/ACDC_processed/", "training")
seq, template = train_dataset[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/raftkevin/lib/python3.10/site-packages/nibabel/loadsave.py:90, in load(filename, **kwargs)
#      89 try:
# ---> 90     stat_result = os.stat(filename)
#      91 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datasets/ACDC_processed/training/patient059_z_2.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 train_dataset = datasets.ACDCDataset("../datasets/ACDC_processed/", "training")
# ----> 2 seq, template = train_dataset[0]
#
# File ~/manal/RAFT/core/datasets.py:42, in ACDCDataset.__getitem__(self, key)
#      40         raise IndexError("The index (%d) is out of range." % key)
#      41     # get the data from direct index
# ---> 42     return self.get_item_from_index(key)
#      43 else:
#      44     raise TypeError("Invalid argument type.")
#
# File ~/manal/RAFT/core/datasets.py:54, in ACDCDataset.get_item_from_index(self, index)
#      52 def get_item_from_index(self, index):
#      53     seq_path = self.seq_f_list[index]
# ---> 54     seq = nib.load("datasets/ACDC_processed/"+self.mode+"/"+seq_path).get_fdata() # np array [H, W, N]
#      55     to_tensor = tv.transforms.ToTensor()
#      56     seq_tensor = to_tensor(seq) # tensor [N, H, W]
#
# File ~/miniconda3/envs/raftkevin/lib/python3.10/site-packages/nibabel/loadsave.py:92, in load(filename, **kwargs)
#      90     stat_result = os.stat(filename)
#      91 except OSError:
# ---> 92     raise FileNotFoundError(f"No such file or no access: '{filename}'")
#      93 if stat_result.st_size <= 0:
#      94     raise ImageFileError(f"Empty file: '{filename}'")
#
# FileNotFoundError: No such file or no access: 'datasets/ACDC_processed/training/patient059_z_2.nii.gz'

# %%
print("This is 1 sequence")
fig = plt.figure(figsize=(20, 20))
columns = 5
rows = 4
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(seq[i,:,:])
plt.show()
# Out:
# This is 1 sequence

# %%
print("This is the corresponding template")
plt.imshow(template[0,:,:])
# Out:
# This is the corresponding template
